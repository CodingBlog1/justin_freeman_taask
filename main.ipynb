# %%
#import Libraries
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None

# %%
#Load the dataset
data = pd.read_csv("Play_By_Play_2018_2022.csv",encoding="ISO-8859-1")
# data['Species'].unique()
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_14068\2488183092.py:2: DtypeWarning: Columns (180,181,183,184,190,191,194,195,198,199,204,205,206,207,210,211,214,215,219,220,221,223,225,227,234,235,236,237,238,239,244,245,246,249,250,254,255,256,261,263,264,267,268,269,270,284,285,302) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Play_By_Play_2018_2022.csv",encoding="ISO-8859-1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231999 entries, 0 to 231998
# Columns: 373 entries, Unnamed: 0 to pass_oe
# dtypes: float64(174), int64(39), object(160)
# memory usage: 660.2+ MB

# %%
data.describe()
# Out:
#           Unnamed: 0        play_id   old_game_id           week  \
# count  231999.000000  231999.000000  2.319990e+05  231999.000000
# mean   116000.000000    2133.169996  2.020090e+09       9.206419
# std     66972.486888    1246.855875  1.399867e+06       5.271703
# min         1.000000       1.000000  2.018091e+09       1.000000
# 25%     58000.500000    1062.000000  2.019093e+09       5.000000
# 50%    116000.000000    2113.000000  2.020110e+09       9.000000
# 75%    173999.500000    3178.000000  2.021112e+09      14.000000
# max    231999.000000    5921.000000  2.022122e+09      22.000000
#
#         yardline_100  quarter_seconds_remaining  half_seconds_remaining  \
# count  212307.000000              231893.000000           231893.000000
# mean       48.631133                 407.466776              800.975420
# std        24.356269                 282.231480              562.024293
# min         1.000000                   0.000000                0.000000
# ...

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data.shape
# Out:
# (231999, 372)

# %%
data.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'out_of_bounds', 'home_opening_kickoff', 'qb_epa', 'xyac_epa',
#        'xyac_mean_yardage', 'xyac_median_yardage', 'xyac_success', 'xyac_fd',
#        'xpass', 'pass_oe'],
#       dtype='object', length=372)

# %%
data.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2018_01_ATL_PHI   2018090600       PHI       ATL         REG
# 1       37  2018_01_ATL_PHI   2018090600       PHI       ATL         REG
# 2       52  2018_01_ATL_PHI   2018090600       PHI       ATL         REG
# 3       75  2018_01_ATL_PHI   2018090600       PHI       ATL         REG
# 4      104  2018_01_ATL_PHI   2018090600       PHI       ATL         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     0
# 1     1     ATL         away     PHI  ...             0                     0
# 2     1     ATL         away     PHI  ...             0                     0
# 3     1     ATL         away     PHI  ...             1                     0
# 4     1     ATL         away     PHI  ...             1                     0
#
# ...

# %%
# 1.You can eliminate all rows where 'play' does not equal 1 (this eliminates unhelpful plays)
df_usefull_player = data[data['play'] == 1]
df_usefull_player.reset_index(inplace=True)

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ... out_of_bounds  \
# ...

# %%
#2 . So what I'd like is to add a column to the play by play file above for "Pos_Offensive_Coordinator"
#which will match the field 'posteam' to "Team" and the field 'season' to the corresponding column... 
#this will tell us who the offensive coordinator was for each offense
offensive_coordinator_df = pd.read_excel("Offensive Coordinators.xlsx")
offensive_coordinator_df.columns
# Out:
# Index([     'Team',        2022,        2021,        2020,        2019,
#               2018, '2022 Code', '2021 Code', '2020 Code', '2019 Code',
#        '2018 Code'],
#       dtype='object')

# %%
# offensive_coordinator_df[[2022,"Team"]]

for i, row in df_usefull_player.iterrows():
    if row['posteam'] in offensive_coordinator_df['Team'].values and row['season'] in list(df_usefull_player.season.unique()):
        df_usefull_player.loc[i,'Pos_Offensive_Coordinator'] = offensive_coordinator_df.loc[offensive_coordinator_df['Team'] == row['posteam'], row['season']].values[0]
print("append")
# Out:
# append

# %%
#3. Add another column called "Pos_Head_Coach" that points to either "home_coach" or "away_coach" based on whether "posteam_type" is home or away
# If "posteam_type" = home, set "Pos_Head_Coach" to "home_coach"
# If "posteam_type" = away, set "Post_Head_Coach" to "away_coach"

df_usefull_player['Pos_Head_Coach'] = df_usefull_player.apply(lambda x: x['home_coach'] if x['posteam_type'] == 'home' else x['away_coach'], axis=1)

# %%
# df_usefull_player['Pos_Head_Coach'].unique()

# %%
#4. Using data from current season (that is already known) + 2 former seasons, add a column called "Pos_OC_Pass_OE" and a column called "Pos_HC_Pass_OE"
# Example for value of "Pos_OC_Pass_OE" in week 5 of 2022, it should calculate based on all plays from season = 2021 (all weeks), season = 2020 (all weeks), and season = 2022 (weeks 1 through 4 only)
# Calculation for "Pos_OC_Pass_OE" sums "pass_oe" for the Offensive Coordinate (Pos_Offensive_Coordinator) over relevant sample divided by total number of plays
# Calculation for "Pos_HC_Pass_OE" sums "pass_oe" for the Offensive Coordinate (Pos_Head_Coach) over relevant sample divided by total number of plays



# so the values should be dynamic based on the point in time for that game... example when determining a coach's 
# Pos_OC_Pass_OE during week = 10 and season = 2022 for CoachABC, the calc should be sum of pass_oe where OC = CoachABC, 
# season 2020 or 2021, plus season = 2022 and week < 10

# %%
# (2018 in (list(df_usefull_player['season'])) & (1 in list(df_usefull_player['week'])))

# %%
for  i,row in df_usefull_player.iterrows():
    # s = row['season']
    # w = row['week']

    # print(df_usefull_player[row(['season']-2).isin(df_usefull_player['season']) & (row['week']-1).isin(df_usefull_player['week'])])
    
    s = row['season']-2
    w = row['week']-1
    # print("222222",df_usefull_player['season'] >= row['season'] - 2)
    
    
    df=s in (list(df_usefull_player['season']) & (w in (list(df_usefull_player['week']))))

    df
    # relevant_data = df_usefull_player[s.isin(df_usefull_player['season'])]
    # print(relevant_data['season'].head())


    # total_plays = len(relevant_data)
    # oc_plays = relevant_data[(relevant_data['Pos_Offensive_Coordinator'] == row['Pos_Offensive_Coordinator'])]['pass_oe'].sum()
    # hc_plays = relevant_data[(relevant_data['Pos_Head_Coach'] == row['Pos_Head_Coach'])]['pass_oe'].sum()

    # row['Pos_OC_Pass_OE'] = oc_plays / total_plays
    # row['Pos_HC_Pass_OE'] = hc_plays / total_plays


    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 12
#       8 w = row['week']-1
#       9 # print("222222",df_usefull_player['season'] >= row['season'] - 2)
# ---> 12 df=s in (list(df_usefull_player['season']) & (w in (list(df_usefull_player['week']))))
#      14 df
#      15 # relevant_data = df_usefull_player[s.isin(df_usefull_player['season'])]
#      16 # print(relevant_data['season'].head())
#      17
#    (...)
#      23 # row['Pos_OC_Pass_OE'] = oc_plays / total_plays
#      24 # row['Pos_HC_Pass_OE'] = hc_plays / total_plays
#
# TypeError: unsupported operand type(s) for &: 'list' and 'bool'

# %%
# df_usefull_player[['play_id','Pos_OC_Pass_OE','Pos_HC_Pass_OE','week','season','Pos_Head_Coach','Pos_Offensive_Coordinator','pass_oe']][(df_usefull_player['season'] == 2022) & (df_usefull_player['Pos_Head_Coach'] == "Mike Vrabel") & (df_usefull_player['week'] == 10)]

# %%
# # for  i, row in df_usefull_player.iterrows():
# #     print(row['season'],row['week'])
# #     try:
# #         df = df_usefull_player[(row['season'] in ([2020,2021,2022])) & (row['week'] in (week))]
# #         print(df[['week','season','Pos_Head_Coach','pass_oe']])
# #         break

# #     except:
# #         pass




# ##################y348734y8734y83y

# for  i,row in df_usefull_player.iterrows():
#     s = row['season']
#     w = row['week']

#     new= df_usefull_player[(s - 2) & (w-1)]

# %%
df_usefull_player['season'][161:162]
# Out:
# 161    2018
# Name: season, dtype: int64

# %%
# relevant_data = df_usefull_player[(df_usefull_player['season'] == 2021) | (df_usefull_player['season'] == 2020) | ((df_usefull_player['season'] ==2022) & (df_usefull_player['week'] <= 4))]

# %%
# groups = relevant_data.groupby(['Pos_Offensive_Coordinator', 'Pos_Head_Coach'])

# %%
# total_plays = groups['pass_oe'].count()
# total_plays

# %%
# df_usefull_player["Pos_Offensive_Coordinator"].nunique()
# Out:
# 82

# %%
# df_usefull_player["Pos_Head_Coach"].nunique()
# Out:
# 65

# %%
# pass_oe_sum = groups['pass_oe'].sum()
# pass_oe_sum

# %%
# df_usefull_player

# %%
# pos_oc_pass_oe = pass_oe_sum / total_plays
# pos_hc_pass_oe = pass_oe_sum / total_plays

# pos_oc_pass_oe
# Out:
# Pos_Offensive_Coordinator  Pos_Head_Coach
# Adam Gase                  Adam Gase         -3.356923
# Adam Stenavich             Matt LaFleur      -3.815780
# Alex Van Pelt              Kevin Stefanski   -5.792567
# Anthony Lynn               Dan Campbell      -5.121444
# Arthur Smith               Mike Vrabel       -8.756512
#                                                 ...
# Tim Kelly                  Bill O'Brien      -0.295105
#                            David Culley      -2.831012
#                            Romeo Crennel      7.348200
# Todd Downing               Mike Vrabel       -7.089316
# Wes Phillips               Kevin O'Connell    3.017623
# Name: pass_oe, Length: 68, dtype: float64

# %%
# pos_oc_pass_oe.get("Justin Outten", 0)
# # df_usefull_player['Pos_Offensive_Coordinator'][0]
# pos_oc_pass_oe = dict(zip(pos_oc_pass_oe.index, pos_oc_pass_oe.values))
# pos_hc_pass_oe = dict(zip(pos_hc_pass_oe.index, pos_hc_pass_oe.values))

# %%
# df_usefull_player['Pos_OC_Pass_OE'] = df_usefull_player.apply(lambda x: pos_oc_pass_oe.get((x['Pos_Offensive_Coordinator'], x['Pos_Head_Coach']), 0), axis=1)
# df_usefull_player['Pos_HC_Pass_OE'] = df_usefull_player.apply(lambda x: pos_hc_pass_oe.get((x['Pos_Offensive_Coordinator'], x['Pos_Head_Coach']), 0), axis=1)

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ... xyac_mean_yardage  \
# ...

# %%
#5. Using data from current season (that is already known) + 2 former seasons, add a column called "Pos_OC_Success" and a column called "Pos_HC_Success"
#a. We will define success as the sum of 'success' column divided by number of plays

# %%
# df_usefull_player

# %%
groups = df_usefull_player.groupby(['Pos_Offensive_Coordinator', 'Pos_Head_Coach'])

total_plays = groups['success'].count()
success_sum = groups['success'].sum()
pos_oc_success = success_sum / total_plays
pos_hc_success = success_sum / total_plays


df_usefull_player['Pos_OC_Success'] = df_usefull_player.apply(lambda x: pos_oc_success.get((x['Pos_Offensive_Coordinator'], x['Pos_Head_Coach']), 0), axis=1)
df_usefull_player['Pos_HC_Success'] = df_usefull_player.apply(lambda x: pos_hc_success.get((x['Pos_Offensive_Coordinator'], x['Pos_Head_Coach']), 0), axis=1)

# %%
df_usefull_player.head(20)
# Out:
#     index  play_id          game_id  old_game_id home_team away_team  \
# 0       2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1       3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2       4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3       5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4       6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# 5       7      168  2018_01_ATL_PHI   2018090600       PHI       ATL
# 6       8      190  2018_01_ATL_PHI   2018090600       PHI       ATL
# 7       9      214  2018_01_ATL_PHI   2018090600       PHI       ATL
# 8      10      235  2018_01_ATL_PHI   2018090600       PHI       ATL
# 9      11      256  2018_01_ATL_PHI   2018090600       PHI       ATL
# 10     12      278  2018_01_ATL_PHI   2018090600       PHI       ATL
# 11     13      299  2018_01_ATL_PHI   2018090600       PHI       ATL
# 12     14      320  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...

# %%
# print(df_usefull_player['weather'].to_string())

# %%
#6.Add a column called "Weather_Type" that takes the first part of the string from 'weather' field
# Examples:
# Clear
# Rainy
# Cloudy
# Partly Cloudy
# Etc.


def get_weather_type(row): 
    weather = row.split('Temp')[0]
    
    return weather

df_usefull_player['Weather_Type'] = df_usefull_player['weather'].apply(get_weather_type)

# %%
# df_usefull_player["spread_line"].count()
df_usefull_player[['season', 'week', 'pass_oe', 'Pos_Head_Coach']]
# Out:
#         season  week    pass_oe     Pos_Head_Coach
# 0         2018     1        NaN          Dan Quinn
# 1         2018     1  41.288257          Dan Quinn
# 2         2018     1 -49.825913          Dan Quinn
# 3         2018     1 -46.798116          Dan Quinn
# 4         2018     1  54.204091          Dan Quinn
# ...        ...   ...        ...                ...
# 174801    2022    15  23.735290  Nathaniel Hackett
# 174802    2022    15   4.721403  Nathaniel Hackett
# 174803    2022    15  19.814630    Kliff Kingsbury
# 174804    2022    15  16.258250    Kliff Kingsbury
# 174805    2022    15  10.287440    Kliff Kingsbury
#
# [174806 rows x 4 columns]

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ...   xyac_fd     xpass  \
# ...

# %%
# 7. Add a column called "Implied_Home_Team_Total", "Implied_Away_Team_Total", "Implied_Pos_Team_Total" and "Implied_Def_Team_Total"
# Implied_Home_Team_Total = total_line/2 + spread_line
# Implied_Away_Team_Total = total_line/2 - spread_line
# Implied_Pos_Team_Total = either Implied_Home_Team_Total or Implied_Away_Team_Total based on whether 'posteam_type' = home or away



#----------------------------------------------------modified------------------------------------------------------------------------------
# For the implied totals that you created... i need to modify that formula
# Implied_Home_Team_Total = total_line/2 + spread_line/2
# Implied_Away_Team_Total = total_line/2 - spread_line/2


df_usefull_player['Implied_Home_Team_Total'] = df_usefull_player['total_line']/2 + df_usefull_player['spread_line']/2
df_usefull_player['Implied_Away_Team_Total'] = df_usefull_player['total_line']/2 - df_usefull_player['spread_line']/2

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ...    pass_oe  \
# ...

# %%
# df_usefull_player['Implied_Pos_Team_Total'] = df_usefull_player.apply(lambda x: x['Implied_Home_Team_Total'] if x['posteam_type'] == 'home' else x['Implied_Away_Team_Total'], axis=1)
# df_usefull_player['Implied_Def_Team_Total'] = df_usefull_player.apply(lambda x: x['Implied_Away_Team_Total'] if x['posteam_type'] == 'away' else x['Implied_Home_Team_Total'], axis=1)

# %%
# Modify Implied_Pos_Team_Total to be equal Implied_Home_Team_Total if posteam_type = home
# Modify Implied_Pos_Team_Total to b equal Implied_Away_Team_Total if posteam_type = away

df_usefull_player.loc[df_usefull_player['posteam_type'] == 'home', 'Implied_Pos_Team_Total'] = df_usefull_player['Implied_Home_Team_Total']
df_usefull_player.loc[df_usefull_player['posteam_type'] == 'away', 'Implied_Pos_Team_Total'] = df_usefull_player['Implied_Away_Team_Total']

# %%
# df_usefull_player.head(12)

# %%
# df_usefull_player.loc[df_usefull_player['posteam_type'] == 'home']  #174795	, 19.50

# %%
# Modify Implied_Def_Team_Total to be equal Implied_Away_Team_Total if posteam_type = home
# Modify Implied_Def_Team_Total to be equal Implied_Home_Team_Total if posteam_type = away



df_usefull_player.loc[df_usefull_player['posteam_type'] == 'home', 'Implied_Def_Team_Total'] = df_usefull_player['Implied_Away_Team_Total']
df_usefull_player.loc[df_usefull_player['posteam_type'] == 'away', 'Implied_Def_Team_Total'] = df_usefull_player['Implied_Home_Team_Total']

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ...     Pos_Head_Coach  \
# ...

# %%
#8.Add a column called "Posteam_Spread" that returns spread_line if posteam_type = away or returns spread_line*-1 if posteam_type = home

df_usefull_player['Posteam_Spread'] = df_usefull_player['spread_line'] * df_usefull_player.apply(lambda x: 1 if x['posteam_type'] == 'away' else -1 ,axis=1)

# %%
df_usefull_player
# Out:
#          index  play_id          game_id  old_game_id home_team away_team  \
# 0            2       52  2018_01_ATL_PHI   2018090600       PHI       ATL
# 1            3       75  2018_01_ATL_PHI   2018090600       PHI       ATL
# 2            4      104  2018_01_ATL_PHI   2018090600       PHI       ATL
# 3            5      125  2018_01_ATL_PHI   2018090600       PHI       ATL
# 4            6      146  2018_01_ATL_PHI   2018090600       PHI       ATL
# ...        ...      ...              ...          ...       ...       ...
# 174801  231988     1549  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174802  231990     1577  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174803  231993     1640  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174804  231994     1662  2022_15_ARI_DEN   2022121805       DEN       ARI
# 174805  231996     1681  2022_15_ARI_DEN   2022121805       DEN       ARI
#
#        season_type  week posteam posteam_type  ... Pos_OC_Pass_OE  \
# ...

# %%
df_usefull_player['Weather_Type'].unique()
# Out:
# array(['Cloudy ', 'Rain ', 'Clear ', 'Partly Cloudy ', 'Cloudy and Cool ',
#        'Sunny ', 'Controlled Climate ', 'N/A (Indoors) ',
#        'Scattered Showers ', 'N/A Indoor ', '', 'Fair ',
#        'Rain Chance 40% ', 'Light Rain ', 'Clear and sunny ',
#        'Mostly sunny ', 'Sunny and warm ', 'Mostly Cloudy ',
#        'Mostly Sunny ', 'Partly Sunny ', 'Partly clear ',
#        'Clear and Sunny ', 'Partly cloudy ', 'cloudy ',
#        'Cloudy, 50% change of rain ', 'Clear and Cool ', 'Sunny, Windy ',
#        'Clear skies ', 'Sunny and clear ', 'Hazy ', 'Indoors ',
#        'Mostly Sunny Skies ', 'Mostly cloudy ', 'Partly Clouidy ',
#        'Snow ', 'Sunny Skies ', 'Clear Skies ', 'Overcast ',
#        'T: 51; H: 55; W: NW 10 mph ', 'Rain shower ', 'Cloudy, Rain ',
#        'Clear and cold ', 'Rainy ', 'Sunny and cold ', 'Breezy ', 'N/A ',
#        'Partly cloudy and mild ', 'Mostly Clear ', 'partly cloudy ',
#        'Light rain ', 'N/A Indoors ', 'Partly sunny ',
# ...

# %%
df_usefull_player.drop('index',inplace=True,axis=1)

# %%
df_usefull_player.to_csv("play_play_output.csv",index=False)

# %%
# df_usefull_player.to_excel("play_play_output.xlsx",index=False) 
# df_usefull_player['total']
# Out:
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30
#           ..
# 174801    39
# 174802    39
# 174803    39
# 174804    39
# 174805    39
# Name: total, Length: 174806, dtype: int64

# %%
# 2 members
# terms... need to convert posteam and defteam variables into home and away variables
# Implied_Pos_Team_Total
# Implied _Def_Team_Total
# Since pos and def do not match up to home and away, we need to create new columns for Implied _Home_Team_Total and Implied_Away_Team_Total... same is true for:
# a. Posteam_Spread 
# b. Pos_OC_Pass_OE
# c. Pos_OC_Success
# d. Pos_HC_Pass_OE
# e. Pos_HC_Success
